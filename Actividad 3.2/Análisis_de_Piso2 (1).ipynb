# %%
# Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('Análisis_de_Piso2_Sin_Nulos.csv', index_col=False) 
data.head()
# Out:
#   Ventas Piso 2024 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                9          5          9          1          3         10
# 1              feb        mar        abr        may        jun        jul
# 2                           0          0          0          0          0
# 3                           0          0          0          0          0
# 4                           0          0          0          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...    Unnamed: 21  \
# 0          9          6          3         11  ...  RAKING VENTAS
# 1        ago        sep        oct        nov  ...              0
# 2          0          0          0          0  ...             23
# 3          0          0          0          1  ...              6
# 4          0          0          0          0  ...              0
#
#             Unnamed: 22               979               811     Unnamed: 25  \
# 0  Dependencia de Piso   Historico de PDM  Historico de SDC  Conversion PDM
# 1                     0                 0                 0               0
# 2                     0                 1                 5               1
# 3                  0.61                59                40            0.31
# 4                     0                 1                 1               0
#
#       Unnamed: 26 Factor minimo mejor vendedor   \
# 0  Conversion SDC                   Factor  PDM
# 1               0                             0
# 2               0                          1.00
# 3            0.02                          3.28
# 4               0                          0.00
#
#   Factor minimo mejor vendedor .1 Unnamed: 29 Unnamed: 30
# 0                     Factor  SDC  Raking PDM  Raking SDC
# 1                               0           0           0
# 2                            5.00           1          20
# 3                            2.22           7          10
# 4                            0.00           0           0
#
# [5 rows x 31 columns]

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Ventas Piso 2024                       42 non-null     str
#  1   Unnamed: 1                             42 non-null     str
#  2   Unnamed: 2                             42 non-null     str
#  3   Unnamed: 3                             42 non-null     str
#  4   Unnamed: 4                             42 non-null     str
#  5   Unnamed: 5                             42 non-null     str
#  6   Unnamed: 6                             42 non-null     str
#  7   Unnamed: 7                             42 non-null     str
#  8   Unnamed: 8                             42 non-null     str
#  9   Unnamed: 9                             42 non-null     str
#  10  Unnamed: 10                            42 non-null     str
#  11  Unnamed: 11                            42 non-null     str
#  12  Ventas Piso 2025                       42 non-null     str
#  13  Unnamed: 13                            42 non-null     str
#  14  Unnamed: 14                            42 non-null     str
#  15  Unnamed: 15                            42 non-null     str
#  16  * se actualiza al reportar en Sale-U   42 non-null     str
#  17  Unnamed: 17                            42 non-null     str
#  18  Unnamed: 18                            42 non-null     str
#  19  Unnamed: 19                            42 non-null     str
#  20  263                                    42 non-null     str
#  21  Unnamed: 21                            42 non-null     str
#  22  Unnamed: 22                            42 non-null     str
#  23  979                                    42 non-null     str
#  24  811                                    42 non-null     str
#  25  Unnamed: 25                            42 non-null     str
#  26  Unnamed: 26                            42 non-null     str
#  27  Factor minimo mejor vendedor           42 non-null     str
#  28  Factor minimo mejor vendedor .1        42 non-null     str
#  29  Unnamed: 29                            42 non-null     str
#  30  Unnamed: 30                            42 non-null     str
# dtypes: str(31)
# memory usage: 10.3 KB

# %%
# Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Ventas Piso 2024                         0
# Unnamed: 1                               0
# Unnamed: 2                               0
# Unnamed: 3                               0
# Unnamed: 4                               0
# Unnamed: 5                               0
# Unnamed: 6                               0
# Unnamed: 7                               0
# Unnamed: 8                               0
# Unnamed: 9                               0
# Unnamed: 10                              0
# Unnamed: 11                              0
# Ventas Piso 2025                         0
# Unnamed: 13                              0
# Unnamed: 14                              0
# Unnamed: 15                              0
# * se actualiza al reportar en Sale-U     0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# 263                                      0
# Unnamed: 21                              0
# Unnamed: 22                              0
# 979                                      0
# 811                                      0
# Unnamed: 25                              0
# Unnamed: 26                              0
# Factor minimo mejor vendedor             0
# Factor minimo mejor vendedor .1          0
# Unnamed: 29                              0
# Unnamed: 30                              0
# dtype: int64

# %%
# Convertir DataFrame a CSV
data.to_csv("Análisis_de_piso2_sin_outliers.csv", index=False)
